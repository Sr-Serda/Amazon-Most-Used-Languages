# %%
import requests

# %%
import pandas as pd

# %%
from dotenv import load_dotenv
import os
load_dotenv()

auth_token = os.getenv('GITHUB_AUTH_TOKEN')

headers = {'Authorization': 'Bearer ' + auth_token,
           'X-GitHub-Api-Version': '2022-11-28'}

auth_token
# Out:
# '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'

# %%
auth_token = os.getenv('GITHUB_AUTH_TOKEN')

headers = {'Authorization': 'Bearer ' + auth_token,
           'X-GitHub-Api-Version': '2022-11-28'}

auth_token
# Out:
# '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'

# %%
username = 'amzn'
url = f"https://api.github.com/users/{username}/followers"
response = requests.get(url, headers=headers)
response.json()
followers = response.json()

# %%
followers_list_sublist = []
followers_list = []
page_num = 1

while True:
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        response.raise_for_status()
        
        data = response.json()
        
        if not data:
            break
        
        # codigo anterior

        if page_num == 100:
            break
        
        followers_list_sublist.append(data)
        followers_list.extend(data)
        page_num += 1
    except Exception as error:
        print(f'Erro na pagina: {page_num}: {error}')
        break

# %%
       
url_page
# Out:
# 'https://api.github.com/users/amzn/followers?page=60'

# %%
# Supondo que followers_list é uma lista de dicionários com informações dos seguidores
# Para armazenar o resultado caso o usuário seja encontrado

# Verificar a lista completa de seguidores
def find_user(user_to_find):
    found_user = None
    for user in followers_list:
        if user.get('login') == user_to_find:
            found_user = user
            break

    # Exibir o resultado
    if found_user:
        print(f"Usuário encontrado: {found_user}")
    else:
        print(f"Usuário {user_to_find} não encontrado na lista de seguidores.")

# %%
find_user('Sr-Serda')
# Out:
# Usuário encontrado: {'login': 'Sr-Serda', 'id': 174975197, 'node_id': 'U_kgDOCm3o3Q', 'avatar_url': 'https://avatars.githubusercontent.com/u/174975197?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Sr-Serda', 'html_url': 'https://github.com/Sr-Serda', 'followers_url': 'https://api.github.com/users/Sr-Serda/followers', 'following_url': 'https://api.github.com/users/Sr-Serda/following{/other_user}', 'gists_url': 'https://api.github.com/users/Sr-Serda/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Sr-Serda/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Sr-Serda/subscriptions', 'organizations_url': 'https://api.github.com/users/Sr-Serda/orgs', 'repos_url': 'https://api.github.com/users/Sr-Serda/repos', 'events_url': 'https://api.github.com/users/Sr-Serda/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Sr-Serda/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}

# %%
followers_name = []
for list in followers_list_sublist:
    for name in list:
        found_name = name.get('login')
        followers_name.append(found_name)
        
followers_name
# Out:
# ['tkersey',
#  'njonsson',
#  'bangpound',
#  'vincentkoc',
#  'Rud5G',
#  'mlsj1',
#  'syug',
#  'varungupta',
#  'esneko',
#  'neopunisher',
#  'jazzwang',
#  'begoon',
#  'fly51fly',
#  'fallenpegasus',
#  'fribeiro1',
#  'brase',
#  'chchrist',
#  'massimoselvi',
#  'ScottJWalter',
#  'mikeputnam',
#  'adeelahmad',
#  'mindcrime',
#  'informaticadiaz',
#  'MarceloNascimento',
#  'skowronek',
#  'dsoul',
#  'dmsbilas',
#  'thimslugga',
#  'leecardona',
#  'shyuan',
#  'nara',
#  'dning1',
#  'openam',
#  'semsphy',
#  'DaemonCahill',
#  'Cambera',
#  'riyadparvez',
#  'nattfodd',
#  'mitaka',
#  'ZhangYunfang',
#  'temosy',
#  'threadstonesecure',
#  'manuelhunziker',
#  'ambagasdowa',
#  'daball',
#  'pedro-lima',
#  'alexharvey',
#  'josh-fisher',
#  'subidit',
#  'pdevenraj',
#  'jtmoon79',
#  'nerandell',
#  'raghuboosetty',
#  'tdmalone',
#  '34code',
#  'burib',
#  'whn09',
#  'bobbyearl',
#  'alishir',
#  'ahlfors',
#  'bsrz',
#  'mailmahee',
#  'mihkels',
#  'daefresh',
#  'dofstar',
#  'codee',
#  'LisaDelaney',
#  'EdZava',
#  'pmanolak',
#  'kistasi',
#  'tariqwest',
#  'afelicioni',
#  'firebitsbr',
#  'glaucodiogo',
#  'gunkaragoz',
#  'manjunathd',
#  'afonsoalban',
#  'rsaa',
#  'hvn0413',
#  'duxing2007',
#  'ste93cry',
#  'terran1942',
#  'jloiola',
#  'itanoss',
#  'anujku',
#  'thesobercoder',
#  'bygbyron3',
#  'rickymaciel',
#  'KevinGimbel',
#  'd-shimizu',
#  'zsp0817',
#  'konamo',
#  'voldyman',
#  'golf-x',
#  'alexjennings',
#  'Spinfusor',
#  'somaditya',
#  'apjowen',
#  'usui-tk',
#  'dengqixing',
#  'Davi-He',
#  'godsoul',
#  'kumar-nitish',
#  'toku345',
#  'snoop0x7b',
#  'PandaBlessing',
#  'andyuls',
#  'juanjoruiz2109',
#  'mangualero',
#  'haydenthai',
#  'proverbs53',
#  'Rajivhost',
#  'universewrld',
#  'dpapageo',
#  'HJiefeng',
#  'larsfi',
#  'kkpan11',
#  'plumcube',
#  'magigo',
#  'ahmadfaizalbh',
#  'flukebox',
#  'jakebrinkmann',
#  'simar1998',
#  'CheeseTurtle',
#  'AAbasinejad',
#  'virtuoushub',
#  'huamichaelchen',
#  'mumblepins',
#  'b3nkos',
#  'bretdarby',
#  'srinitude',
#  'the-watchmaker',
#  'codinggooner',
#  'kimpenguin',
#  'pthbinh92',
#  'weisberg',
#  'ace-coder',
#  'infinitedreams9586',
#  'tusharsoni08',
#  'hoansgithub',
#  'ritesh-singh',
#  'schallerala',
#  'alexxyjiang',
#  'XiaomingX',
#  'star-fx',
#  'amavlyanov',
#  'garciparedes',
#  'keshabb',
#  'mcybulski',
#  'o-kakade',
#  'designisaverb',
#  's0nlxaftrsh0ck',
#  'darasat',
#  'mklemann-com',
#  'nikkidada',
#  'tiloyi',
#  'roykalony',
#  'zhangxiangdong',
#  'thomasdalbert',
#  'LavenderDaisy',
#  'edisona',
#  'Steven-Acomb',
#  'kevcooper',
#  'jodavaho',
#  'side9show',
#  'teeksingh',
#  'kevingrondin',
#  'koyashiro',
#  'devikirang',
#  'unlitdev',
#  'well1791',
#  'mleziva',
#  'ajian005',
#  'ykaidashov',
#  'ankur-gupta',
#  'Malacarne',
#  'anand-b',
#  'stdexception',
#  'MatterhornProject',
#  'tolgabuyuktanir',
#  'cash2059',
#  'rajabalaji-mp',
#  'anobil',
#  'radiochickenwax',
#  'vedamj01',
#  'jafferlin',
#  'yixiuhua',
#  'rodazuero',
#  'JustCallMe-AK',
#  'henriquerick',
#  'JoeyCai',
#  'Wyvernslay3r',
#  'gabrlyg',
#  'paulosiciliano',
#  'martinvaldivia',
#  'rdczhby',
#  'mys328',
#  'billykwok',
#  'andrey-berenda',
#  'sinhang',
#  'Pal3love',
#  'Lakshmiaddepalli',
#  'mohamed-abdelsattar92',
#  'rawer886',
#  'junhong202',
#  'thanhcsf',
#  'junaid109',
#  'arpitgo4',
#  'roykhoury',
#  'bafeiyu',
#  'Ylmzef',
#  'everXu',
#  'anlexN',
#  'Janujan',
#  'fwblcz',
#  'elaineleung',
#  'djinl520',
#  'protyay',
#  'selfishprimate',
#  'Mwalthery',
#  'GregAllenSmith',
#  'zgover',
#  'avestura',
#  'aspindle',
#  'pqrsooo',
#  'evanshrestha',
#  'bos-hieu',
#  'hanautoparts4u',
#  'sonimonish00',
#  'ljesparis',
#  'imvikramn',
#  'massivelivefun',
#  'garrettrh',
#  'adanone',
#  'ghishadow',
#  'shower1986',
#  'mseld',
#  'JasonYe88',
#  'seshurajup',
#  'xiaopizi19',
#  'pelamlio',
#  'Asavarkhul',
#  'ajay340',
#  'custadian',
#  'KlwntSingh',
#  'FelixFeliciant',
#  'learnerzhang',
#  'gamedebug',
#  'jonathanarodr',
#  'baboooin',
#  'osama-ahmed',
#  'nir-zilberman',
#  'changyongyong',
#  'bigDP',
#  'WajahatSiddiqui',
#  'markjohnlucas',
#  'Vaibhav',
#  'manavchoudhary',
#  'mrcharlierace',
#  'nikolaospapachristou',
#  'CallmeTorre',
#  'jcarlos001',
#  'vslala',
#  'peterjlay',
#  'Ngel-Castro',
#  'rilek',
#  'dawei-wang',
#  'George-Petrovski',
#  'DominikHorn',
#  'bptorao',
#  'JeffUssing',
#  'edstgo',
#  'yxblee',
#  'barisates',
#  'ankkrish',
#  'pratickRoy',
#  'pereirakadu',
#  'justinsamuel92',
#  'ryanulep',
#  'dotsnangles',
#  '609151318',
#  'RyanAugust',
#  'dbarrington',
#  'knhnd',
#  'akari0624',
#  'noid11',
#  'ioing',
#  'AruulmozhivarmanS',
#  'Tusharjagi',
#  'ivaylo-yordanov',
#  'rramirez0203',
#  'emullaraj',
#  'theranajayant',
#  'jkjavier',
#  'mcguegi',
#  'nbhirud',
#  'fischerleon',
#  'UmutSERIFLER',
#  'zhu0823',
#  'Joe192168',
#  'SanHacks',
#  'LindaHaviv',
#  'ball582',
#  'dmitrykrisko',
#  'qmajid',
#  'we1l1n',
#  'jhhe66',
#  'thangnm93',
#  'NikhilRyan',
#  'dongzhuoyao',
#  'jason1004',
#  'xuelangqingkong',
#  'godobyte',
#  'chanffdavid',
#  'anomaly-88',
#  'undabah',
#  'aymenbelarbi',
#  'ashish936',
#  'giotramu',
#  '0xlkda',
#  'guilhermebc',
#  'SMBgurus',
#  'brentclay',
#  'mate-h',
#  'artur-sak13',
#  'yorshreynoso',
#  'yehuizhang',
#  'AAdewunmi',
#  'balao7',
#  'flaviopavim',
#  'Zenidog8',
#  'aiwongs',
#  'kalsyanpradeep',
#  'charaton',
#  'jadanah',
#  'vonzou',
#  'jaymahfudy',
#  'maxsxu',
#  'keita-hino',
#  'KyuDounSim',
#  'depers',
#  'Anirudh257',
#  'jmartins-sh',
#  'satyarajreddy',
#  'Prithvish04',
#  'AnsonHwang86',
#  'xzm2004260',
#  'anirudhbagri',
#  'STCYC',
#  'rsmelo92',
#  'StrangerCoug',
#  'keren123',
#  'paraskevasleivadaros',
#  'Grimgog',
#  'noodanee',
#  'alobe',
#  'zhuzixian520',
#  'JadeCong',
#  'VitorSouza7512',
#  'ProfessionalBoatDrifter',
#  'dancause',
#  'ltlwill',
#  'graceko22',
#  'paletode',
#  'Timotej979',
#  'erenaslandev',
#  'serhiiklenachov',
#  'camerondurham',
#  'khanhhuy288',
#  'gstair',
#  'wwfyde',
#  'hotsticker',
#  'ningfc',
#  'RishabhKr97',
#  'jiangoz',
#  'ardasatata',
#  'Murplugg',
#  'tanvirstreame',
#  'kworkbee',
#  'arnab-ray',
#  'yuriykuntsyak',
#  'StarDustTwinkle',
#  'bahadirsahin',
#  'SMSesay',
#  'jamestiotio',
#  'anuj97',
#  'yaelBrown',
#  'motmaytinh',
#  'desaidn',
#  'NoxGamingQC',
#  'aravinthakannan',
#  'lingjiekong',
#  'diohsb',
#  'janviyao',
#  'hijiki51',
#  'mksarge',
#  'pradeepkni382',
#  'rdnasim',
#  'shrinidhibarthur',
#  'StrangeKnowledgeIncresed',
#  'Austin47',
#  'shokriw',
#  'franklin-monreal',
#  'xxh031203',
#  'dororoholic',
#  'chipro',
#  'lossfunc',
#  'feapaydin',
#  'loumalouomega',
#  'james-sungjae-lee',
#  'garyhtou',
#  'd3v2null',
#  'msweetland',
#  'wrslatz',
#  'alfaisal7313',
#  'jrjm1111',
#  'mitutitu16',
#  'ShuhaoZQGG',
#  'akashsathyan',
#  'sushant-joshi',
#  'chrisskhoury',
#  'jeremychauvet',
#  'alxporto',
#  'riturajDas',
#  'Logicus03',
#  'chinchillajared',
#  'isabelchaves',
#  'shikharsaxena98',
#  'flukelaster',
#  'rjuer',
#  'mussieh',
#  'pawa2007',
#  'lintsai',
#  '6thpath',
#  'nj1787',
#  'rockychang7',
#  'hanwgyu',
#  'wudangqibujie',
#  'DihanDai',
#  'drewfrost',
#  'bixo-d',
#  'MUmarJaved',
#  'contimatteo',
#  'amaankulshreshtha',
#  'surajsahani',
#  'hackenbacker',
#  'petronem',
#  'my1795',
#  'Pzoom522',
#  'SpeicherA',
#  'nityansuman',
#  'akbarboghani',
#  'hahacyd',
#  'wangtiechuan',
#  'lynmison',
#  'linshan-ma',
#  'anaghkanungo7',
#  'RickyC0626',
#  'WladFrazao',
#  'Ming0217',
#  'caesar-one',
#  'xuepengwei',
#  'Ishanna',
#  'pavankalyan-nvs',
#  'JoeRMiller',
#  'luwen193',
#  'devStarscream',
#  'nkn6294live',
#  'FanJups',
#  'ShwetaShivangi',
#  'amwi04',
#  'mnk400',
#  'pd14196',
#  'samirdjelal',
#  'tychodev321',
#  'TheFJS14',
#  'Baleryom',
#  'caitinc',
#  'almokhtarbr',
#  'andreacip',
#  'alexanderafanasov',
#  'duranbe',
#  'thapaashis110',
#  'soccernut',
#  'mdobro1',
#  'royswale',
#  'saneknight',
#  'AnhTrieu',
#  'janmarkuslanger',
#  'morinyan',
#  'gujiacun',
#  'adileone',
#  'BIGChask',
#  'mapjx',
#  'fuhaoma',
#  'DXLZ',
#  'nuffQuantumSayd',
#  'nikfed280199',
#  'kekemao00',
#  'lamsd',
#  'anuq',
#  'igorasantos',
#  'metaphor0',
#  'iashutoshtiwari',
#  'yaravi',
#  'skippermin',
#  'masakiasami',
#  'gurtejrehal',
#  'huannvttd98',
#  'SantosCristiano',
#  'thatbeautifuldream',
#  'happyqq',
#  'iameduardod',
#  'wuchunfu',
#  'venkate5hgunda',
#  'NousheenAnwar',
#  'whuhxb',
#  'ks1990cn',
#  'ronnielutaro',
#  'Samutichev',
#  'jongan69',
#  'nmoisess',
#  'kayericson',
#  'tjolr',
#  'LuGO0',
#  'rishikavikondala',
#  'lodhik9',
#  'cultivate5253',
#  'elafifi',
#  'akazyti',
#  'boomer2752',
#  'Luccasoli',
#  'benmassaoud',
#  'abheesht17',
#  'ShrivatsAgrawal',
#  'farhan-2202',
#  'HebaElGalad',
#  'himanshututeja1998',
#  'sevenhqj',
#  'AsadAmir111',
#  'CWHer',
#  'Pei1133',
#  'proKress',
#  'SamuelMaculuve',
#  'pasenchenko',
#  'jinjidong',
#  'eemailme',
#  'Nikronic',
#  'Razdeep',
#  'jkh920184196',
#  'jimbrig',
#  'FenTheDev',
#  'Dxdzy86',
#  'ThaoNhienNguyen-Erika',
#  'chunkSpadunk',
#  'patrick22414',
#  'diguapao',
#  'pseshadri9',
#  'Jiahuan-Pei',
#  'AdityaSoni17',
#  'shelthack',
#  'dykderrick',
#  'johngunerli',
#  'aijls',
#  'akashmdkml',
#  'Menotron',
#  'smustafa75',
#  'nanaboat1',
#  'eshack94',
#  'S-Swaroop',
#  'HellCat1024',
#  'Karim-53',
#  'EthanC-8',
#  'nitinnbisht',
#  'ericpark123',
#  'Matheus-ESW',
#  'allenduchaoyuan',
#  'Yulv-git',
#  'hexolan',
#  'moqsien',
#  'MilleniumSpark',
#  'sagsango',
#  'Programador89',
#  'robertgro',
#  'JasonMoon95',
#  'limeng92',
#  'raashidanwar',
#  'jackpan123',
#  'bshreddy',
#  'TsukasaSeto',
#  'almiracioly',
#  'PallaviVarandani',
#  'alvinlal',
#  'Rookl',
#  'awabasher',
#  'Katsukiniwa',
#  'huuquyet',
#  'PMcTwist',
#  'hqng',
#  'rkv0id',
#  'MadeInLondon',
#  'SimonVonXCVII',
#  'sigsant',
#  'celikgokhun',
#  'shiva0612',
#  'rroohit',
#  'jk4freedom',
#  'kyamashiro',
#  'LasVegasBilly',
#  'Turbocaspal',
#  'davnunes',
#  'afondiel',
#  'johnnyrtrentin',
#  'stnorbi',
#  'stacyrymer86',
#  'zero-null',
#  'jh9875',
#  'eduardoteles17',
#  'GITWHB',
#  'devinkg',
#  'ricardosuman',
#  'mencarellic',
#  'rabbithophop',
#  'ftf1218',
#  'hirawatt',
#  'adilet-saken',
#  'marcomamprin',
#  'Thejuskbenny',
#  'TomasDavidYe',
#  'nanaxumu',
#  'adyilam',
#  'GabrielFerrante',
#  '13995595007',
#  'tinahuang222',
#  'edgaramirbekian',
#  'Bhavuk-Garg',
#  'Mzon2857',
#  'thiagomares',
#  'skleee',
#  'mjsheikh',
#  'anishamalde',
#  'easy147',
#  'TeddyCom1',
#  'prabhumns',
#  'VSXV',
#  'HyunjunA',
#  'harishravi121',
#  'Habib16051',
#  'iamharvey',
#  'rahul-zomato',
#  'ricardopra',
#  'avanishvyas',
#  'inframarauder',
#  'YjqZhouxiao',
#  'adhamsalama',
#  'LuoTailong',
#  'AtaraxiaZ',
#  'hyanzhang',
#  'sovansambath-phann',
#  'rkej',
#  'jinshuye',
#  'ibn-khafagah',
#  'kartikeytewari',
#  'md-arfin-cse',
#  'johncruyff14',
#  'johan-lab',
#  'ambanerjee',
#  'bzamith',
#  'deviknitkkr',
#  'Abirul',
#  'ranefattesingh',
#  'nesakobi',
#  'yungwarlock',
#  'hunghg255',
#  'matoszz',
#  'andrewdge',
#  'RobertConde',
#  'rksamu',
#  'hartl3y94',
#  'ramitkataria',
#  'saarthdeshpande',
#  'leechenze',
#  'Dexterzprotege',
#  'alan713',
#  'sandrawilczynski',
#  'ManojTGN',
#  'Debarshi95',
#  'gauharayub',
#  'GowthamSk1',
#  'PolyTroid',
#  'middas-0706',
#  'seanwynwins',
#  'WendyYanto',
#  'sangamesh-kodge',
#  'claudsonbarros',
#  'yotamnahum',
#  'huiminlim',
#  'sumukhteja',
#  'JankinTian',
#  'Pcharlot13',
#  'djmcclary',
#  'theroyakash',
#  'sadoreko',
#  'billsenxu',
#  'MarcoSantonastasi',
#  'cheungfujai',
#  'amadsalmon',
#  'infinitepower18',
#  'ashr4f1arr2ad',
#  'akbarabdul80',
#  'rgdyy',
#  'shayanekat',
#  'fellipematos',
#  'Disciple0fMarx',
#  'VE5ETA',
#  'KlinKlinKlin',
#  'ishu-thakur',
#  'brijeshbhalodiya',
#  'zaaakher',
#  'XRLZX8',
#  'soumyadbanik',
#  'zhnzhang',
#  'yhf98',
#  'xjhofernandes',
#  'gauravagrwal',
#  'torys877',
#  'juanca-jimi',
#  'mapy1874',
#  'JohnDNC',
#  'zeelsheladiya',
#  'ImKunYoung',
#  'EduardHov',
#  'kamelbendi',
#  'mitchell-cheng',
#  'Soumil-Bhattacharya',
#  'mahmoud-elghonemy',
#  'johnmccants002',
#  'samedsemihs',
#  'moramadan98',
#  'aymandarwish',
#  'porum',
#  'HongLouyemeng',
#  'maniac1122',
#  'Sambit650',
#  'haja-fgabriel',
#  'kohring',
#  'okonri',
#  'paulohenz',
#  'leopoldoH',
#  'cnhuz',
#  'liltommy1dev',
#  'Wwillers',
#  'owini',
#  'amirmojarad',
#  'RichardZj',
#  'hellomikko',
#  'MarcoSteinke',
#  'yanquanfahei',
#  'acox216',
#  'smy1999',
#  'switcombe',
#  'anujchoudhary-17',
#  'mazrean',
#  'XrosLiang',
#  '994Simone',
#  'matheussooares',
#  'Mystic-77',
#  'bruno-aires',
#  'Jirigesi',
#  'PerfectYellow',
#  'imokhtar',
#  'GvHarish9894',
#  'ArthurAnastopulos',
#  'w3dg',
#  'guilefoylegaurav',
#  'denmj',
#  'frankxzAmazon',
#  'ericwidjaja',
#  'mirfanaslam',
#  'nayeonshin',
#  'xiaozhiob',
#  'u-yas',
#  'smelouah',
#  'icqmula',
#  'ndagan',
#  'dmascheck',
#  'Abhirajnow',
#  'sanjuchandra',
#  'sadiqshaik123',
#  'cccaimingjian',
#  'anurag01a',
#  'masrafi115',
#  'Liebmann5',
#  'sm-heard',
#  'Abhijrathod',
#  'leonardoknakagawa',
#  'agastaldellomaccomit',
#  'steffiypx',
#  'AdnanAaddi',
#  'MaxDeveloper16',
#  'hchen19',
#  'leonardofhy',
#  'tenpa007',
#  'gtrman97',
#  'clay-curry',
#  'MuffinAmor',
#  'amiranbari',
#  'rushilenekar20',
#  'soma2000-lang',
#  'jin-sungdae',
#  'Git-Codder',
#  'Ayush-Pujari-07',
#  'songziqwq',
#  'goillotc',
#  '2019-GitHub-Chu',
#  'Tarsisnbs',
#  'dylenchang',
#  'chinkin707',
#  'azwpayne',
#  'frankporco',
#  'surajongithub1986',
#  'adithya1010',
#  'sametcn99',
#  'HUNG-rushb',
#  'Aditya-Khemka',
#  'chanwoo00106',
#  'FrankQixiangGao',
#  'WonJoongLee',
#  'alikemalozgumus',
#  'Codesmaster-lab',
#  'gwd666',
#  'dhanrajswami',
#  'Supriyo8799',
#  'Maher-RJ',
#  'Dajun-2019',
#  '0xa3k5',
#  'LuanGomes12',
#  'stevenrsewell',
#  'Symon629',
#  'martintaylor1635',
#  'kranti2201',
#  'prad-j',
#  'jaquespavan',
#  'huiyouyou',
#  'vignesh5535',
#  'huai-jie',
#  'bipin0x01',
#  'chrichri17',
#  'GessioMori',
#  'TylerMamrot',
#  'danmslamt',
#  'Pecorari',
#  '1MuhammadFarhanAslam',
#  'br8km',
#  'najmehn00',
#  'Uplift-0508',
#  'samtimur',
#  'ajmalbinnizam',
#  'TatsuyaNakagoshi',
#  'jigordev',
#  'NonymousMorlock',
#  'EfeAcar6431',
#  'akinfelami',
#  'avstreamdevpro',
#  'kqiq',
#  'NaoyaTatetsu',
#  'mijung-in-11st',
#  'simonjgr',
#  'osman-nazir',
#  'Vigneshkumar212',
#  'mrwanggang-crazy',
#  'BraeSleepn',
#  'avadhutjc',
#  'MLHaddon',
#  'Capital-SetMawHtay',
#  'sumairq',
#  'jcork4real',
#  'samr874',
#  'aditya-repos',
#  'spencerlepine',
#  'calbergs',
#  'yusuke-z',
#  'Yuri-Mendes',
#  'jimmysmits',
#  'Drag0nf1y',
#  'JohnDoll2023',
#  'Saipraneeth99',
#  'santoshlite',
#  'vinodpatildev',
#  'leejoonhun',
#  'mmhamdy',
#  'lorenonzi',
#  'baisedongtian',
#  'arqam365',
#  'hiyyg',
#  'zustems',
#  'VitorAkira-me',
#  'Jesus-Retr0',
#  'solfonte',
#  'PrideStudio',
#  'PriyamJha0124',
#  'Matt-Bulk',
#  'xiao-cy',
#  'meijihatakeyama',
#  'galichy79',
#  'thefaheemkhan',
#  'Flaiers',
#  'HenriqueFurtado-Dev',
#  'Derokkk',
#  'Shahna-C',
#  'chosungmann',
#  'Ethan-Ka',
#  'grahamwaters',
#  'deezeddd',
#  'jaymepsantos',
#  'mohamedhabibwork',
#  'Rayane-Aboud',
#  'hueiwhfa',
#  'anurag1504t',
#  'rudra-code-creator',
#  'rajveer43',
#  'Kushan2k',
#  'Thilak-KN',
#  'Tiger15cub',
#  'AesisGit',
#  'rafaelporfiriobarros',
#  'OBud75',
#  'yosefkiros',
#  'benzebra',
#  'HamdanAr',
#  'ralintuscano',
#  'rhattox',
#  'FurkanEdizkan',
#  'Tyalor',
#  'SegaGLm',
#  'celso-na-teixeira',
#  'nilesh05apr',
#  'EM51641',
#  'seanpm2001',
#  'thiagomendonca-eu',
#  'rainmana',
#  'dylanhood',
#  'chris0765',
#  'JohnPPinto',
#  'Pquar',
#  'oss-mad',
#  'TrNgTien',
#  'Mindula-Dilthushan',
#  'AHANCIT',
#  'sebaminaya0',
#  'd-t-n',
#  'vinoth-techie',
#  'rbuchmann77',
#  'Rameshraj55',
#  'SeifEldinMohamed',
#  'SteCC',
#  'daniel-dqsdatalabs',
#  'JoseRicardoPE',
#  'PhumyJS',
#  'yuyingjun0922',
#  'shakhzodtojiev',
#  'ShabbirHasan1',
#  'klkuoguru',
#  'ggopal13',
#  'angeloS-98',
#  'yagikota',
#  'DougRog',
#  'ipez98',
#  'litingyes',
#  'buddy1276',
#  'rdbender',
#  'balajiCubie',
#  'uivid64',
#  'deevanshu-k',
#  'linquint',
#  'pjiang15',
#  'jeanhackpy',
#  'PhaedrusFlow',
#  'nguyen-duy-tan',
#  'Tpeach9474',
#  'KennyOliver',
#  'ronnieangeles',
#  'Lucas-sudo-dev',
#  'mahmud0v',
#  'carnate-tech',
#  'AldairAvelino',
#  'mertkilix',
#  'Ghost1386',
#  'asmnajmussakibkhan',
#  'harshitclub',
#  'ketanxos',
#  'istellaliu',
#  'QuantumBoy1010',
#  'polygonnedpotato',
#  'MadushanNimantha',
#  'Choikyudong',
#  'Harshi-itaSinha',
#  'anthowest',
#  'emiltervo',
#  'gustavoturin',
#  ...]

# %%
followers_url = []
for list in followers_list_sublist:
    for url in list:
        found_url = url.get('html_url')
        followers_url.append(found_url)
        
followers_url
# Out:
# ['https://github.com/tkersey',
#  'https://github.com/njonsson',
#  'https://github.com/bangpound',
#  'https://github.com/vincentkoc',
#  'https://github.com/Rud5G',
#  'https://github.com/mlsj1',
#  'https://github.com/syug',
#  'https://github.com/varungupta',
#  'https://github.com/esneko',
#  'https://github.com/neopunisher',
#  'https://github.com/jazzwang',
#  'https://github.com/begoon',
#  'https://github.com/fly51fly',
#  'https://github.com/fallenpegasus',
#  'https://github.com/fribeiro1',
#  'https://github.com/brase',
#  'https://github.com/chchrist',
#  'https://github.com/massimoselvi',
#  'https://github.com/ScottJWalter',
#  'https://github.com/mikeputnam',
#  'https://github.com/adeelahmad',
#  'https://github.com/mindcrime',
#  'https://github.com/informaticadiaz',
#  'https://github.com/MarceloNascimento',
#  'https://github.com/skowronek',
#  'https://github.com/dsoul',
#  'https://github.com/dmsbilas',
#  'https://github.com/thimslugga',
#  'https://github.com/leecardona',
#  'https://github.com/shyuan',
#  'https://github.com/nara',
#  'https://github.com/dning1',
#  'https://github.com/openam',
#  'https://github.com/semsphy',
#  'https://github.com/DaemonCahill',
#  'https://github.com/Cambera',
#  'https://github.com/riyadparvez',
#  'https://github.com/nattfodd',
#  'https://github.com/mitaka',
#  'https://github.com/ZhangYunfang',
#  'https://github.com/temosy',
#  'https://github.com/threadstonesecure',
#  'https://github.com/manuelhunziker',
#  'https://github.com/ambagasdowa',
#  'https://github.com/daball',
#  'https://github.com/pedro-lima',
#  'https://github.com/alexharvey',
#  'https://github.com/josh-fisher',
#  'https://github.com/subidit',
#  'https://github.com/pdevenraj',
#  'https://github.com/jtmoon79',
#  'https://github.com/nerandell',
#  'https://github.com/raghuboosetty',
#  'https://github.com/tdmalone',
#  'https://github.com/34code',
#  'https://github.com/burib',
#  'https://github.com/whn09',
#  'https://github.com/bobbyearl',
#  'https://github.com/alishir',
#  'https://github.com/ahlfors',
#  'https://github.com/bsrz',
#  'https://github.com/mailmahee',
#  'https://github.com/mihkels',
#  'https://github.com/daefresh',
#  'https://github.com/dofstar',
#  'https://github.com/codee',
#  'https://github.com/LisaDelaney',
#  'https://github.com/EdZava',
#  'https://github.com/pmanolak',
#  'https://github.com/kistasi',
#  'https://github.com/tariqwest',
#  'https://github.com/afelicioni',
#  'https://github.com/firebitsbr',
#  'https://github.com/glaucodiogo',
#  'https://github.com/gunkaragoz',
#  'https://github.com/manjunathd',
#  'https://github.com/afonsoalban',
#  'https://github.com/rsaa',
#  'https://github.com/hvn0413',
#  'https://github.com/duxing2007',
#  'https://github.com/ste93cry',
#  'https://github.com/terran1942',
#  'https://github.com/jloiola',
#  'https://github.com/itanoss',
#  'https://github.com/anujku',
#  'https://github.com/thesobercoder',
#  'https://github.com/bygbyron3',
#  'https://github.com/rickymaciel',
#  'https://github.com/KevinGimbel',
#  'https://github.com/d-shimizu',
#  'https://github.com/zsp0817',
#  'https://github.com/konamo',
#  'https://github.com/voldyman',
#  'https://github.com/golf-x',
#  'https://github.com/alexjennings',
#  'https://github.com/Spinfusor',
#  'https://github.com/somaditya',
#  'https://github.com/apjowen',
#  'https://github.com/usui-tk',
#  'https://github.com/dengqixing',
#  'https://github.com/Davi-He',
#  'https://github.com/godsoul',
#  'https://github.com/kumar-nitish',
#  'https://github.com/toku345',
#  'https://github.com/snoop0x7b',
#  'https://github.com/PandaBlessing',
#  'https://github.com/andyuls',
#  'https://github.com/juanjoruiz2109',
#  'https://github.com/mangualero',
#  'https://github.com/haydenthai',
#  'https://github.com/proverbs53',
#  'https://github.com/Rajivhost',
#  'https://github.com/universewrld',
#  'https://github.com/dpapageo',
#  'https://github.com/HJiefeng',
#  'https://github.com/larsfi',
#  'https://github.com/kkpan11',
#  'https://github.com/plumcube',
#  'https://github.com/magigo',
#  'https://github.com/ahmadfaizalbh',
#  'https://github.com/flukebox',
#  'https://github.com/jakebrinkmann',
#  'https://github.com/simar1998',
#  'https://github.com/CheeseTurtle',
#  'https://github.com/AAbasinejad',
#  'https://github.com/virtuoushub',
#  'https://github.com/huamichaelchen',
#  'https://github.com/mumblepins',
#  'https://github.com/b3nkos',
#  'https://github.com/bretdarby',
#  'https://github.com/srinitude',
#  'https://github.com/the-watchmaker',
#  'https://github.com/codinggooner',
#  'https://github.com/kimpenguin',
#  'https://github.com/pthbinh92',
#  'https://github.com/weisberg',
#  'https://github.com/ace-coder',
#  'https://github.com/infinitedreams9586',
#  'https://github.com/tusharsoni08',
#  'https://github.com/hoansgithub',
#  'https://github.com/ritesh-singh',
#  'https://github.com/schallerala',
#  'https://github.com/alexxyjiang',
#  'https://github.com/XiaomingX',
#  'https://github.com/star-fx',
#  'https://github.com/amavlyanov',
#  'https://github.com/garciparedes',
#  'https://github.com/keshabb',
#  'https://github.com/mcybulski',
#  'https://github.com/o-kakade',
#  'https://github.com/designisaverb',
#  'https://github.com/s0nlxaftrsh0ck',
#  'https://github.com/darasat',
#  'https://github.com/mklemann-com',
#  'https://github.com/nikkidada',
#  'https://github.com/tiloyi',
#  'https://github.com/roykalony',
#  'https://github.com/zhangxiangdong',
#  'https://github.com/thomasdalbert',
#  'https://github.com/LavenderDaisy',
#  'https://github.com/edisona',
#  'https://github.com/Steven-Acomb',
#  'https://github.com/kevcooper',
#  'https://github.com/jodavaho',
#  'https://github.com/side9show',
#  'https://github.com/teeksingh',
#  'https://github.com/kevingrondin',
#  'https://github.com/koyashiro',
#  'https://github.com/devikirang',
#  'https://github.com/unlitdev',
#  'https://github.com/well1791',
#  'https://github.com/mleziva',
#  'https://github.com/ajian005',
#  'https://github.com/ykaidashov',
#  'https://github.com/ankur-gupta',
#  'https://github.com/Malacarne',
#  'https://github.com/anand-b',
#  'https://github.com/stdexception',
#  'https://github.com/MatterhornProject',
#  'https://github.com/tolgabuyuktanir',
#  'https://github.com/cash2059',
#  'https://github.com/rajabalaji-mp',
#  'https://github.com/anobil',
#  'https://github.com/radiochickenwax',
#  'https://github.com/vedamj01',
#  'https://github.com/jafferlin',
#  'https://github.com/yixiuhua',
#  'https://github.com/rodazuero',
#  'https://github.com/JustCallMe-AK',
#  'https://github.com/henriquerick',
#  'https://github.com/JoeyCai',
#  'https://github.com/Wyvernslay3r',
#  'https://github.com/gabrlyg',
#  'https://github.com/paulosiciliano',
#  'https://github.com/martinvaldivia',
#  'https://github.com/rdczhby',
#  'https://github.com/mys328',
#  'https://github.com/billykwok',
#  'https://github.com/andrey-berenda',
#  'https://github.com/sinhang',
#  'https://github.com/Pal3love',
#  'https://github.com/Lakshmiaddepalli',
#  'https://github.com/mohamed-abdelsattar92',
#  'https://github.com/rawer886',
#  'https://github.com/junhong202',
#  'https://github.com/thanhcsf',
#  'https://github.com/junaid109',
#  'https://github.com/arpitgo4',
#  'https://github.com/roykhoury',
#  'https://github.com/bafeiyu',
#  'https://github.com/Ylmzef',
#  'https://github.com/everXu',
#  'https://github.com/anlexN',
#  'https://github.com/Janujan',
#  'https://github.com/fwblcz',
#  'https://github.com/elaineleung',
#  'https://github.com/djinl520',
#  'https://github.com/protyay',
#  'https://github.com/selfishprimate',
#  'https://github.com/Mwalthery',
#  'https://github.com/GregAllenSmith',
#  'https://github.com/zgover',
#  'https://github.com/avestura',
#  'https://github.com/aspindle',
#  'https://github.com/pqrsooo',
#  'https://github.com/evanshrestha',
#  'https://github.com/bos-hieu',
#  'https://github.com/hanautoparts4u',
#  'https://github.com/sonimonish00',
#  'https://github.com/ljesparis',
#  'https://github.com/imvikramn',
#  'https://github.com/massivelivefun',
#  'https://github.com/garrettrh',
#  'https://github.com/adanone',
#  'https://github.com/ghishadow',
#  'https://github.com/shower1986',
#  'https://github.com/mseld',
#  'https://github.com/JasonYe88',
#  'https://github.com/seshurajup',
#  'https://github.com/xiaopizi19',
#  'https://github.com/pelamlio',
#  'https://github.com/Asavarkhul',
#  'https://github.com/ajay340',
#  'https://github.com/custadian',
#  'https://github.com/KlwntSingh',
#  'https://github.com/FelixFeliciant',
#  'https://github.com/learnerzhang',
#  'https://github.com/gamedebug',
#  'https://github.com/jonathanarodr',
#  'https://github.com/baboooin',
#  'https://github.com/osama-ahmed',
#  'https://github.com/nir-zilberman',
#  'https://github.com/changyongyong',
#  'https://github.com/bigDP',
#  'https://github.com/WajahatSiddiqui',
#  'https://github.com/markjohnlucas',
#  'https://github.com/Vaibhav',
#  'https://github.com/manavchoudhary',
#  'https://github.com/mrcharlierace',
#  'https://github.com/nikolaospapachristou',
#  'https://github.com/CallmeTorre',
#  'https://github.com/jcarlos001',
#  'https://github.com/vslala',
#  'https://github.com/peterjlay',
#  'https://github.com/Ngel-Castro',
#  'https://github.com/rilek',
#  'https://github.com/dawei-wang',
#  'https://github.com/George-Petrovski',
#  'https://github.com/DominikHorn',
#  'https://github.com/bptorao',
#  'https://github.com/JeffUssing',
#  'https://github.com/edstgo',
#  'https://github.com/yxblee',
#  'https://github.com/barisates',
#  'https://github.com/ankkrish',
#  'https://github.com/pratickRoy',
#  'https://github.com/pereirakadu',
#  'https://github.com/justinsamuel92',
#  'https://github.com/ryanulep',
#  'https://github.com/dotsnangles',
#  'https://github.com/609151318',
#  'https://github.com/RyanAugust',
#  'https://github.com/dbarrington',
#  'https://github.com/knhnd',
#  'https://github.com/akari0624',
#  'https://github.com/noid11',
#  'https://github.com/ioing',
#  'https://github.com/AruulmozhivarmanS',
#  'https://github.com/Tusharjagi',
#  'https://github.com/ivaylo-yordanov',
#  'https://github.com/rramirez0203',
#  'https://github.com/emullaraj',
#  'https://github.com/theranajayant',
#  'https://github.com/jkjavier',
#  'https://github.com/mcguegi',
#  'https://github.com/nbhirud',
#  'https://github.com/fischerleon',
#  'https://github.com/UmutSERIFLER',
#  'https://github.com/zhu0823',
#  'https://github.com/Joe192168',
#  'https://github.com/SanHacks',
#  'https://github.com/LindaHaviv',
#  'https://github.com/ball582',
#  'https://github.com/dmitrykrisko',
#  'https://github.com/qmajid',
#  'https://github.com/we1l1n',
#  'https://github.com/jhhe66',
#  'https://github.com/thangnm93',
#  'https://github.com/NikhilRyan',
#  'https://github.com/dongzhuoyao',
#  'https://github.com/jason1004',
#  'https://github.com/xuelangqingkong',
#  'https://github.com/godobyte',
#  'https://github.com/chanffdavid',
#  'https://github.com/anomaly-88',
#  'https://github.com/undabah',
#  'https://github.com/aymenbelarbi',
#  'https://github.com/ashish936',
#  'https://github.com/giotramu',
#  'https://github.com/0xlkda',
#  'https://github.com/guilhermebc',
#  'https://github.com/SMBgurus',
#  'https://github.com/brentclay',
#  'https://github.com/mate-h',
#  'https://github.com/artur-sak13',
#  'https://github.com/yorshreynoso',
#  'https://github.com/yehuizhang',
#  'https://github.com/AAdewunmi',
#  'https://github.com/balao7',
#  'https://github.com/flaviopavim',
#  'https://github.com/Zenidog8',
#  'https://github.com/aiwongs',
#  'https://github.com/kalsyanpradeep',
#  'https://github.com/charaton',
#  'https://github.com/jadanah',
#  'https://github.com/vonzou',
#  'https://github.com/jaymahfudy',
#  'https://github.com/maxsxu',
#  'https://github.com/keita-hino',
#  'https://github.com/KyuDounSim',
#  'https://github.com/depers',
#  'https://github.com/Anirudh257',
#  'https://github.com/jmartins-sh',
#  'https://github.com/satyarajreddy',
#  'https://github.com/Prithvish04',
#  'https://github.com/AnsonHwang86',
#  'https://github.com/xzm2004260',
#  'https://github.com/anirudhbagri',
#  'https://github.com/STCYC',
#  'https://github.com/rsmelo92',
#  'https://github.com/StrangerCoug',
#  'https://github.com/keren123',
#  'https://github.com/paraskevasleivadaros',
#  'https://github.com/Grimgog',
#  'https://github.com/noodanee',
#  'https://github.com/alobe',
#  'https://github.com/zhuzixian520',
#  'https://github.com/JadeCong',
#  'https://github.com/VitorSouza7512',
#  'https://github.com/ProfessionalBoatDrifter',
#  'https://github.com/dancause',
#  'https://github.com/ltlwill',
#  'https://github.com/graceko22',
#  'https://github.com/paletode',
#  'https://github.com/Timotej979',
#  'https://github.com/erenaslandev',
#  'https://github.com/serhiiklenachov',
#  'https://github.com/camerondurham',
#  'https://github.com/khanhhuy288',
#  'https://github.com/gstair',
#  'https://github.com/wwfyde',
#  'https://github.com/hotsticker',
#  'https://github.com/ningfc',
#  'https://github.com/RishabhKr97',
#  'https://github.com/jiangoz',
#  'https://github.com/ardasatata',
#  'https://github.com/Murplugg',
#  'https://github.com/tanvirstreame',
#  'https://github.com/kworkbee',
#  'https://github.com/arnab-ray',
#  'https://github.com/yuriykuntsyak',
#  'https://github.com/StarDustTwinkle',
#  'https://github.com/bahadirsahin',
#  'https://github.com/SMSesay',
#  'https://github.com/jamestiotio',
#  'https://github.com/anuj97',
#  'https://github.com/yaelBrown',
#  'https://github.com/motmaytinh',
#  'https://github.com/desaidn',
#  'https://github.com/NoxGamingQC',
#  'https://github.com/aravinthakannan',
#  'https://github.com/lingjiekong',
#  'https://github.com/diohsb',
#  'https://github.com/janviyao',
#  'https://github.com/hijiki51',
#  'https://github.com/mksarge',
#  'https://github.com/pradeepkni382',
#  'https://github.com/rdnasim',
#  'https://github.com/shrinidhibarthur',
#  'https://github.com/StrangeKnowledgeIncresed',
#  'https://github.com/Austin47',
#  'https://github.com/shokriw',
#  'https://github.com/franklin-monreal',
#  'https://github.com/xxh031203',
#  'https://github.com/dororoholic',
#  'https://github.com/chipro',
#  'https://github.com/lossfunc',
#  'https://github.com/feapaydin',
#  'https://github.com/loumalouomega',
#  'https://github.com/james-sungjae-lee',
#  'https://github.com/garyhtou',
#  'https://github.com/d3v2null',
#  'https://github.com/msweetland',
#  'https://github.com/wrslatz',
#  'https://github.com/alfaisal7313',
#  'https://github.com/jrjm1111',
#  'https://github.com/mitutitu16',
#  'https://github.com/ShuhaoZQGG',
#  'https://github.com/akashsathyan',
#  'https://github.com/sushant-joshi',
#  'https://github.com/chrisskhoury',
#  'https://github.com/jeremychauvet',
#  'https://github.com/alxporto',
#  'https://github.com/riturajDas',
#  'https://github.com/Logicus03',
#  'https://github.com/chinchillajared',
#  'https://github.com/isabelchaves',
#  'https://github.com/shikharsaxena98',
#  'https://github.com/flukelaster',
#  'https://github.com/rjuer',
#  'https://github.com/mussieh',
#  'https://github.com/pawa2007',
#  'https://github.com/lintsai',
#  'https://github.com/6thpath',
#  'https://github.com/nj1787',
#  'https://github.com/rockychang7',
#  'https://github.com/hanwgyu',
#  'https://github.com/wudangqibujie',
#  'https://github.com/DihanDai',
#  'https://github.com/drewfrost',
#  'https://github.com/bixo-d',
#  'https://github.com/MUmarJaved',
#  'https://github.com/contimatteo',
#  'https://github.com/amaankulshreshtha',
#  'https://github.com/surajsahani',
#  'https://github.com/hackenbacker',
#  'https://github.com/petronem',
#  'https://github.com/my1795',
#  'https://github.com/Pzoom522',
#  'https://github.com/SpeicherA',
#  'https://github.com/nityansuman',
#  'https://github.com/akbarboghani',
#  'https://github.com/hahacyd',
#  'https://github.com/wangtiechuan',
#  'https://github.com/lynmison',
#  'https://github.com/linshan-ma',
#  'https://github.com/anaghkanungo7',
#  'https://github.com/RickyC0626',
#  'https://github.com/WladFrazao',
#  'https://github.com/Ming0217',
#  'https://github.com/caesar-one',
#  'https://github.com/xuepengwei',
#  'https://github.com/Ishanna',
#  'https://github.com/pavankalyan-nvs',
#  'https://github.com/JoeRMiller',
#  'https://github.com/luwen193',
#  'https://github.com/devStarscream',
#  'https://github.com/nkn6294live',
#  'https://github.com/FanJups',
#  'https://github.com/ShwetaShivangi',
#  'https://github.com/amwi04',
#  'https://github.com/mnk400',
#  'https://github.com/pd14196',
#  'https://github.com/samirdjelal',
#  'https://github.com/tychodev321',
#  'https://github.com/TheFJS14',
#  'https://github.com/Baleryom',
#  'https://github.com/caitinc',
#  'https://github.com/almokhtarbr',
#  'https://github.com/andreacip',
#  'https://github.com/alexanderafanasov',
#  'https://github.com/duranbe',
#  'https://github.com/thapaashis110',
#  'https://github.com/soccernut',
#  'https://github.com/mdobro1',
#  'https://github.com/royswale',
#  'https://github.com/saneknight',
#  'https://github.com/AnhTrieu',
#  'https://github.com/janmarkuslanger',
#  'https://github.com/morinyan',
#  'https://github.com/gujiacun',
#  'https://github.com/adileone',
#  'https://github.com/BIGChask',
#  'https://github.com/mapjx',
#  'https://github.com/fuhaoma',
#  'https://github.com/DXLZ',
#  'https://github.com/nuffQuantumSayd',
#  'https://github.com/nikfed280199',
#  'https://github.com/kekemao00',
#  'https://github.com/lamsd',
#  'https://github.com/anuq',
#  'https://github.com/igorasantos',
#  'https://github.com/metaphor0',
#  'https://github.com/iashutoshtiwari',
#  'https://github.com/yaravi',
#  'https://github.com/skippermin',
#  'https://github.com/masakiasami',
#  'https://github.com/gurtejrehal',
#  'https://github.com/huannvttd98',
#  'https://github.com/SantosCristiano',
#  'https://github.com/thatbeautifuldream',
#  'https://github.com/happyqq',
#  'https://github.com/iameduardod',
#  'https://github.com/wuchunfu',
#  'https://github.com/venkate5hgunda',
#  'https://github.com/NousheenAnwar',
#  'https://github.com/whuhxb',
#  'https://github.com/ks1990cn',
#  'https://github.com/ronnielutaro',
#  'https://github.com/Samutichev',
#  'https://github.com/jongan69',
#  'https://github.com/nmoisess',
#  'https://github.com/kayericson',
#  'https://github.com/tjolr',
#  'https://github.com/LuGO0',
#  'https://github.com/rishikavikondala',
#  'https://github.com/lodhik9',
#  'https://github.com/cultivate5253',
#  'https://github.com/elafifi',
#  'https://github.com/akazyti',
#  'https://github.com/boomer2752',
#  'https://github.com/Luccasoli',
#  'https://github.com/benmassaoud',
#  'https://github.com/abheesht17',
#  'https://github.com/ShrivatsAgrawal',
#  'https://github.com/farhan-2202',
#  'https://github.com/HebaElGalad',
#  'https://github.com/himanshututeja1998',
#  'https://github.com/sevenhqj',
#  'https://github.com/AsadAmir111',
#  'https://github.com/CWHer',
#  'https://github.com/Pei1133',
#  'https://github.com/proKress',
#  'https://github.com/SamuelMaculuve',
#  'https://github.com/pasenchenko',
#  'https://github.com/jinjidong',
#  'https://github.com/eemailme',
#  'https://github.com/Nikronic',
#  'https://github.com/Razdeep',
#  'https://github.com/jkh920184196',
#  'https://github.com/jimbrig',
#  'https://github.com/FenTheDev',
#  'https://github.com/Dxdzy86',
#  'https://github.com/ThaoNhienNguyen-Erika',
#  'https://github.com/chunkSpadunk',
#  'https://github.com/patrick22414',
#  'https://github.com/diguapao',
#  'https://github.com/pseshadri9',
#  'https://github.com/Jiahuan-Pei',
#  'https://github.com/AdityaSoni17',
#  'https://github.com/shelthack',
#  'https://github.com/dykderrick',
#  'https://github.com/johngunerli',
#  'https://github.com/aijls',
#  'https://github.com/akashmdkml',
#  'https://github.com/Menotron',
#  'https://github.com/smustafa75',
#  'https://github.com/nanaboat1',
#  'https://github.com/eshack94',
#  'https://github.com/S-Swaroop',
#  'https://github.com/HellCat1024',
#  'https://github.com/Karim-53',
#  'https://github.com/EthanC-8',
#  'https://github.com/nitinnbisht',
#  'https://github.com/ericpark123',
#  'https://github.com/Matheus-ESW',
#  'https://github.com/allenduchaoyuan',
#  'https://github.com/Yulv-git',
#  'https://github.com/hexolan',
#  'https://github.com/moqsien',
#  'https://github.com/MilleniumSpark',
#  'https://github.com/sagsango',
#  'https://github.com/Programador89',
#  'https://github.com/robertgro',
#  'https://github.com/JasonMoon95',
#  'https://github.com/limeng92',
#  'https://github.com/raashidanwar',
#  'https://github.com/jackpan123',
#  'https://github.com/bshreddy',
#  'https://github.com/TsukasaSeto',
#  'https://github.com/almiracioly',
#  'https://github.com/PallaviVarandani',
#  'https://github.com/alvinlal',
#  'https://github.com/Rookl',
#  'https://github.com/awabasher',
#  'https://github.com/Katsukiniwa',
#  'https://github.com/huuquyet',
#  'https://github.com/PMcTwist',
#  'https://github.com/hqng',
#  'https://github.com/rkv0id',
#  'https://github.com/MadeInLondon',
#  'https://github.com/SimonVonXCVII',
#  'https://github.com/sigsant',
#  'https://github.com/celikgokhun',
#  'https://github.com/shiva0612',
#  'https://github.com/rroohit',
#  'https://github.com/jk4freedom',
#  'https://github.com/kyamashiro',
#  'https://github.com/LasVegasBilly',
#  'https://github.com/Turbocaspal',
#  'https://github.com/davnunes',
#  'https://github.com/afondiel',
#  'https://github.com/johnnyrtrentin',
#  'https://github.com/stnorbi',
#  'https://github.com/stacyrymer86',
#  'https://github.com/zero-null',
#  'https://github.com/jh9875',
#  'https://github.com/eduardoteles17',
#  'https://github.com/GITWHB',
#  'https://github.com/devinkg',
#  'https://github.com/ricardosuman',
#  'https://github.com/mencarellic',
#  'https://github.com/rabbithophop',
#  'https://github.com/ftf1218',
#  'https://github.com/hirawatt',
#  'https://github.com/adilet-saken',
#  'https://github.com/marcomamprin',
#  'https://github.com/Thejuskbenny',
#  'https://github.com/TomasDavidYe',
#  'https://github.com/nanaxumu',
#  'https://github.com/adyilam',
#  'https://github.com/GabrielFerrante',
#  'https://github.com/13995595007',
#  'https://github.com/tinahuang222',
#  'https://github.com/edgaramirbekian',
#  'https://github.com/Bhavuk-Garg',
#  'https://github.com/Mzon2857',
#  'https://github.com/thiagomares',
#  'https://github.com/skleee',
#  'https://github.com/mjsheikh',
#  'https://github.com/anishamalde',
#  'https://github.com/easy147',
#  'https://github.com/TeddyCom1',
#  'https://github.com/prabhumns',
#  'https://github.com/VSXV',
#  'https://github.com/HyunjunA',
#  'https://github.com/harishravi121',
#  'https://github.com/Habib16051',
#  'https://github.com/iamharvey',
#  'https://github.com/rahul-zomato',
#  'https://github.com/ricardopra',
#  'https://github.com/avanishvyas',
#  'https://github.com/inframarauder',
#  'https://github.com/YjqZhouxiao',
#  'https://github.com/adhamsalama',
#  'https://github.com/LuoTailong',
#  'https://github.com/AtaraxiaZ',
#  'https://github.com/hyanzhang',
#  'https://github.com/sovansambath-phann',
#  'https://github.com/rkej',
#  'https://github.com/jinshuye',
#  'https://github.com/ibn-khafagah',
#  'https://github.com/kartikeytewari',
#  'https://github.com/md-arfin-cse',
#  'https://github.com/johncruyff14',
#  'https://github.com/johan-lab',
#  'https://github.com/ambanerjee',
#  'https://github.com/bzamith',
#  'https://github.com/deviknitkkr',
#  'https://github.com/Abirul',
#  'https://github.com/ranefattesingh',
#  'https://github.com/nesakobi',
#  'https://github.com/yungwarlock',
#  'https://github.com/hunghg255',
#  'https://github.com/matoszz',
#  'https://github.com/andrewdge',
#  'https://github.com/RobertConde',
#  'https://github.com/rksamu',
#  'https://github.com/hartl3y94',
#  'https://github.com/ramitkataria',
#  'https://github.com/saarthdeshpande',
#  'https://github.com/leechenze',
#  'https://github.com/Dexterzprotege',
#  'https://github.com/alan713',
#  'https://github.com/sandrawilczynski',
#  'https://github.com/ManojTGN',
#  'https://github.com/Debarshi95',
#  'https://github.com/gauharayub',
#  'https://github.com/GowthamSk1',
#  'https://github.com/PolyTroid',
#  'https://github.com/middas-0706',
#  'https://github.com/seanwynwins',
#  'https://github.com/WendyYanto',
#  'https://github.com/sangamesh-kodge',
#  'https://github.com/claudsonbarros',
#  'https://github.com/yotamnahum',
#  'https://github.com/huiminlim',
#  'https://github.com/sumukhteja',
#  'https://github.com/JankinTian',
#  'https://github.com/Pcharlot13',
#  'https://github.com/djmcclary',
#  'https://github.com/theroyakash',
#  'https://github.com/sadoreko',
#  'https://github.com/billsenxu',
#  'https://github.com/MarcoSantonastasi',
#  'https://github.com/cheungfujai',
#  'https://github.com/amadsalmon',
#  'https://github.com/infinitepower18',
#  'https://github.com/ashr4f1arr2ad',
#  'https://github.com/akbarabdul80',
#  'https://github.com/rgdyy',
#  'https://github.com/shayanekat',
#  'https://github.com/fellipematos',
#  'https://github.com/Disciple0fMarx',
#  'https://github.com/VE5ETA',
#  'https://github.com/KlinKlinKlin',
#  'https://github.com/ishu-thakur',
#  'https://github.com/brijeshbhalodiya',
#  'https://github.com/zaaakher',
#  'https://github.com/XRLZX8',
#  'https://github.com/soumyadbanik',
#  'https://github.com/zhnzhang',
#  'https://github.com/yhf98',
#  'https://github.com/xjhofernandes',
#  'https://github.com/gauravagrwal',
#  'https://github.com/torys877',
#  'https://github.com/juanca-jimi',
#  'https://github.com/mapy1874',
#  'https://github.com/JohnDNC',
#  'https://github.com/zeelsheladiya',
#  'https://github.com/ImKunYoung',
#  'https://github.com/EduardHov',
#  'https://github.com/kamelbendi',
#  'https://github.com/mitchell-cheng',
#  'https://github.com/Soumil-Bhattacharya',
#  'https://github.com/mahmoud-elghonemy',
#  'https://github.com/johnmccants002',
#  'https://github.com/samedsemihs',
#  'https://github.com/moramadan98',
#  'https://github.com/aymandarwish',
#  'https://github.com/porum',
#  'https://github.com/HongLouyemeng',
#  'https://github.com/maniac1122',
#  'https://github.com/Sambit650',
#  'https://github.com/haja-fgabriel',
#  'https://github.com/kohring',
#  'https://github.com/okonri',
#  'https://github.com/paulohenz',
#  'https://github.com/leopoldoH',
#  'https://github.com/cnhuz',
#  'https://github.com/liltommy1dev',
#  'https://github.com/Wwillers',
#  'https://github.com/owini',
#  'https://github.com/amirmojarad',
#  'https://github.com/RichardZj',
#  'https://github.com/hellomikko',
#  'https://github.com/MarcoSteinke',
#  'https://github.com/yanquanfahei',
#  'https://github.com/acox216',
#  'https://github.com/smy1999',
#  'https://github.com/switcombe',
#  'https://github.com/anujchoudhary-17',
#  'https://github.com/mazrean',
#  'https://github.com/XrosLiang',
#  'https://github.com/994Simone',
#  'https://github.com/matheussooares',
#  'https://github.com/Mystic-77',
#  'https://github.com/bruno-aires',
#  'https://github.com/Jirigesi',
#  'https://github.com/PerfectYellow',
#  'https://github.com/imokhtar',
#  'https://github.com/GvHarish9894',
#  'https://github.com/ArthurAnastopulos',
#  'https://github.com/w3dg',
#  'https://github.com/guilefoylegaurav',
#  'https://github.com/denmj',
#  'https://github.com/frankxzAmazon',
#  'https://github.com/ericwidjaja',
#  'https://github.com/mirfanaslam',
#  'https://github.com/nayeonshin',
#  'https://github.com/xiaozhiob',
#  'https://github.com/u-yas',
#  'https://github.com/smelouah',
#  'https://github.com/icqmula',
#  'https://github.com/ndagan',
#  'https://github.com/dmascheck',
#  'https://github.com/Abhirajnow',
#  'https://github.com/sanjuchandra',
#  'https://github.com/sadiqshaik123',
#  'https://github.com/cccaimingjian',
#  'https://github.com/anurag01a',
#  'https://github.com/masrafi115',
#  'https://github.com/Liebmann5',
#  'https://github.com/sm-heard',
#  'https://github.com/Abhijrathod',
#  'https://github.com/leonardoknakagawa',
#  'https://github.com/agastaldellomaccomit',
#  'https://github.com/steffiypx',
#  'https://github.com/AdnanAaddi',
#  'https://github.com/MaxDeveloper16',
#  'https://github.com/hchen19',
#  'https://github.com/leonardofhy',
#  'https://github.com/tenpa007',
#  'https://github.com/gtrman97',
#  'https://github.com/clay-curry',
#  'https://github.com/MuffinAmor',
#  'https://github.com/amiranbari',
#  'https://github.com/rushilenekar20',
#  'https://github.com/soma2000-lang',
#  'https://github.com/jin-sungdae',
#  'https://github.com/Git-Codder',
#  'https://github.com/Ayush-Pujari-07',
#  'https://github.com/songziqwq',
#  'https://github.com/goillotc',
#  'https://github.com/2019-GitHub-Chu',
#  'https://github.com/Tarsisnbs',
#  'https://github.com/dylenchang',
#  'https://github.com/chinkin707',
#  'https://github.com/azwpayne',
#  'https://github.com/frankporco',
#  'https://github.com/surajongithub1986',
#  'https://github.com/adithya1010',
#  'https://github.com/sametcn99',
#  'https://github.com/HUNG-rushb',
#  'https://github.com/Aditya-Khemka',
#  'https://github.com/chanwoo00106',
#  'https://github.com/FrankQixiangGao',
#  'https://github.com/WonJoongLee',
#  'https://github.com/alikemalozgumus',
#  'https://github.com/Codesmaster-lab',
#  'https://github.com/gwd666',
#  'https://github.com/dhanrajswami',
#  'https://github.com/Supriyo8799',
#  'https://github.com/Maher-RJ',
#  'https://github.com/Dajun-2019',
#  'https://github.com/0xa3k5',
#  'https://github.com/LuanGomes12',
#  'https://github.com/stevenrsewell',
#  'https://github.com/Symon629',
#  'https://github.com/martintaylor1635',
#  'https://github.com/kranti2201',
#  'https://github.com/prad-j',
#  'https://github.com/jaquespavan',
#  'https://github.com/huiyouyou',
#  'https://github.com/vignesh5535',
#  'https://github.com/huai-jie',
#  'https://github.com/bipin0x01',
#  'https://github.com/chrichri17',
#  'https://github.com/GessioMori',
#  'https://github.com/TylerMamrot',
#  'https://github.com/danmslamt',
#  'https://github.com/Pecorari',
#  'https://github.com/1MuhammadFarhanAslam',
#  'https://github.com/br8km',
#  'https://github.com/najmehn00',
#  'https://github.com/Uplift-0508',
#  'https://github.com/samtimur',
#  'https://github.com/ajmalbinnizam',
#  'https://github.com/TatsuyaNakagoshi',
#  'https://github.com/jigordev',
#  'https://github.com/NonymousMorlock',
#  'https://github.com/EfeAcar6431',
#  'https://github.com/akinfelami',
#  'https://github.com/avstreamdevpro',
#  'https://github.com/kqiq',
#  'https://github.com/NaoyaTatetsu',
#  'https://github.com/mijung-in-11st',
#  'https://github.com/simonjgr',
#  'https://github.com/osman-nazir',
#  'https://github.com/Vigneshkumar212',
#  'https://github.com/mrwanggang-crazy',
#  'https://github.com/BraeSleepn',
#  'https://github.com/avadhutjc',
#  'https://github.com/MLHaddon',
#  'https://github.com/Capital-SetMawHtay',
#  'https://github.com/sumairq',
#  'https://github.com/jcork4real',
#  'https://github.com/samr874',
#  'https://github.com/aditya-repos',
#  'https://github.com/spencerlepine',
#  'https://github.com/calbergs',
#  'https://github.com/yusuke-z',
#  'https://github.com/Yuri-Mendes',
#  'https://github.com/jimmysmits',
#  'https://github.com/Drag0nf1y',
#  'https://github.com/JohnDoll2023',
#  'https://github.com/Saipraneeth99',
#  'https://github.com/santoshlite',
#  'https://github.com/vinodpatildev',
#  'https://github.com/leejoonhun',
#  'https://github.com/mmhamdy',
#  'https://github.com/lorenonzi',
#  'https://github.com/baisedongtian',
#  'https://github.com/arqam365',
#  'https://github.com/hiyyg',
#  'https://github.com/zustems',
#  'https://github.com/VitorAkira-me',
#  'https://github.com/Jesus-Retr0',
#  'https://github.com/solfonte',
#  'https://github.com/PrideStudio',
#  'https://github.com/PriyamJha0124',
#  'https://github.com/Matt-Bulk',
#  'https://github.com/xiao-cy',
#  'https://github.com/meijihatakeyama',
#  'https://github.com/galichy79',
#  'https://github.com/thefaheemkhan',
#  'https://github.com/Flaiers',
#  'https://github.com/HenriqueFurtado-Dev',
#  'https://github.com/Derokkk',
#  'https://github.com/Shahna-C',
#  'https://github.com/chosungmann',
#  'https://github.com/Ethan-Ka',
#  'https://github.com/grahamwaters',
#  'https://github.com/deezeddd',
#  'https://github.com/jaymepsantos',
#  'https://github.com/mohamedhabibwork',
#  'https://github.com/Rayane-Aboud',
#  'https://github.com/hueiwhfa',
#  'https://github.com/anurag1504t',
#  'https://github.com/rudra-code-creator',
#  'https://github.com/rajveer43',
#  'https://github.com/Kushan2k',
#  'https://github.com/Thilak-KN',
#  'https://github.com/Tiger15cub',
#  'https://github.com/AesisGit',
#  'https://github.com/rafaelporfiriobarros',
#  'https://github.com/OBud75',
#  'https://github.com/yosefkiros',
#  'https://github.com/benzebra',
#  'https://github.com/HamdanAr',
#  'https://github.com/ralintuscano',
#  'https://github.com/rhattox',
#  'https://github.com/FurkanEdizkan',
#  'https://github.com/Tyalor',
#  'https://github.com/SegaGLm',
#  'https://github.com/celso-na-teixeira',
#  'https://github.com/nilesh05apr',
#  'https://github.com/EM51641',
#  'https://github.com/seanpm2001',
#  'https://github.com/thiagomendonca-eu',
#  'https://github.com/rainmana',
#  'https://github.com/dylanhood',
#  'https://github.com/chris0765',
#  'https://github.com/JohnPPinto',
#  'https://github.com/Pquar',
#  'https://github.com/oss-mad',
#  'https://github.com/TrNgTien',
#  'https://github.com/Mindula-Dilthushan',
#  'https://github.com/AHANCIT',
#  'https://github.com/sebaminaya0',
#  'https://github.com/d-t-n',
#  'https://github.com/vinoth-techie',
#  'https://github.com/rbuchmann77',
#  'https://github.com/Rameshraj55',
#  'https://github.com/SeifEldinMohamed',
#  'https://github.com/SteCC',
#  'https://github.com/daniel-dqsdatalabs',
#  'https://github.com/JoseRicardoPE',
#  'https://github.com/PhumyJS',
#  'https://github.com/yuyingjun0922',
#  'https://github.com/shakhzodtojiev',
#  'https://github.com/ShabbirHasan1',
#  'https://github.com/klkuoguru',
#  'https://github.com/ggopal13',
#  'https://github.com/angeloS-98',
#  'https://github.com/yagikota',
#  'https://github.com/DougRog',
#  'https://github.com/ipez98',
#  'https://github.com/litingyes',
#  'https://github.com/buddy1276',
#  'https://github.com/rdbender',
#  'https://github.com/balajiCubie',
#  'https://github.com/uivid64',
#  'https://github.com/deevanshu-k',
#  'https://github.com/linquint',
#  'https://github.com/pjiang15',
#  'https://github.com/jeanhackpy',
#  'https://github.com/PhaedrusFlow',
#  'https://github.com/nguyen-duy-tan',
#  'https://github.com/Tpeach9474',
#  'https://github.com/KennyOliver',
#  'https://github.com/ronnieangeles',
#  'https://github.com/Lucas-sudo-dev',
#  'https://github.com/mahmud0v',
#  'https://github.com/carnate-tech',
#  'https://github.com/AldairAvelino',
#  'https://github.com/mertkilix',
#  'https://github.com/Ghost1386',
#  'https://github.com/asmnajmussakibkhan',
#  'https://github.com/harshitclub',
#  'https://github.com/ketanxos',
#  'https://github.com/istellaliu',
#  'https://github.com/QuantumBoy1010',
#  'https://github.com/polygonnedpotato',
#  'https://github.com/MadushanNimantha',
#  'https://github.com/Choikyudong',
#  'https://github.com/Harshi-itaSinha',
#  'https://github.com/anthowest',
#  'https://github.com/emiltervo',
#  'https://github.com/gustavoturin',
#  ...]

# %%
followers_data_amz = pd.DataFrame()
followers_data_amz['follower_name'] = followers_name
followers_data_amz['follower_url'] = followers_url

# %%
followers_data_amz
# Out:
#      follower_name                     follower_url
# 0          tkersey       https://github.com/tkersey
# 1         njonsson      https://github.com/njonsson
# 2        bangpound     https://github.com/bangpound
# 3       vincentkoc    https://github.com/vincentkoc
# 4            Rud5G         https://github.com/Rud5G
# ...            ...                              ...
# 1743        Len1na        https://github.com/Len1na
# 1744      Larasho6      https://github.com/Larasho6
# 1745      Sahiscs8      https://github.com/Sahiscs8
# 1746        hironb        https://github.com/hironb
# 1747  malisohail72  https://github.com/malisohail72
#
# [1748 rows x 2 columns]

# %%
followers_data_amz.to_excel('followers.xlsx')
